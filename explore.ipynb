# %%
import pandas as pd 

city_names=['Jakarta','Bandung','Makassar','Surabaya','Medan','Yogyakarta','Malang']
population=[498044,964254,497918,8398748,653115,883305,744955]
num_airports=[2,2,8,3,1,3,2]

df=pd.DataFrame({
    'City Name':city_names,
    'Population': population,
    'Airports':num_airports
})

df.describe()
# Out:
#          Population  Airports
# count  7.000000e+00  7.000000
# mean   1.805763e+06  3.000000
# std    2.912645e+06  2.309401
# min    4.979180e+05  1.000000
# 25%    5.755795e+05  2.000000
# 50%    7.449550e+05  2.000000
# 75%    9.237795e+05  3.000000
# max    8.398748e+06  8.000000

# %%
df.describe(include='all')
# Out:
#        City Name    Population  Airports
# count          7  7.000000e+00  7.000000
# unique         7           NaN       NaN
# top      Jakarta           NaN       NaN
# freq           1           NaN       NaN
# mean         NaN  1.805763e+06  3.000000
# std          NaN  2.912645e+06  2.309401
# min          NaN  4.979180e+05  1.000000
# 25%          NaN  5.755795e+05  2.000000
# 50%          NaN  7.449550e+05  2.000000
# 75%          NaN  9.237795e+05  3.000000
# max          NaN  8.398748e+06  8.000000

# %%
import pandas as pd 
body_measurement_df=pd.DataFrame.from_records((
    (2, 83.82, 8.4),
    (4, 99.31, 16.97),
    (3, 96.52, 14.41),
    (6, 114.3, 20.14),
    (4, 101.6, 16.91),
    (2, 86.36, 12.64),
    (3, 92.71, 14.23),
    (2, 85.09, 11.11),
    (2, 85.85, 14.18),
    (5, 106.68, 20.01),
    (4, 99.06, 13.17),
    (5, 109.22, 15.36),
    (4, 100.84, 14.78),
    (6, 115.06, 20.06),
    (2, 84.07, 10.02),
    (7, 121.67, 28.4),
    (3, 94.49, 14.05),
    (6, 116.59, 17.55),
    (7, 121.92, 22.96),
),columns=('age','height_cm','weight_kg'))

body_measurement_df.groupby(by='age').mean()
# Out:
#       height_cm  weight_kg
# age
# 2     85.038000    11.2700
# 3     94.573333    14.2300
# 4    100.202500    15.4575
# 5    107.950000    17.6850
# 6    115.316667    19.2500
# 7    121.795000    25.6800

# %%
body_measurement_df.groupby(by='age').agg({
    'height_cm':'mean',
    'weight_kg':['mean','max','min']
})
# Out:
#       height_cm weight_kg
#            mean      mean    max    min
# age
# 2     85.038000   11.2700  14.18   8.40
# 3     94.573333   14.2300  14.41  14.05
# 4    100.202500   15.4575  16.97  13.17
# 5    107.950000   17.6850  20.01  15.36
# 6    115.316667   19.2500  20.14  17.55
# 7    121.795000   25.6800  28.40  22.96

# %% [markdown]
# # Visualisasi

# %%
import matplotlib.pyplot as plt
cities=('Bogor', 'Bandung', 'Jakarta', 'Semarang', 'Yogyakarta', 
    'Surakarta','Surabaya', 'Medan', 'Makassar')
populations=(45076704, 11626410, 212162757, 19109629, 50819826, 17579085,
    3481, 287750, 785409)

plt.bar(x=cities, height=populations)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd 
df=pd.DataFrame({
    'Cities': cities,
    'Populations': populations,
})
df.sort_values(by='Populations', inplace=True)
plt.barh(y=df['Cities'], width=df['Populations'])
plt.xlabel('populations(Milions)')
plt.title('Populations of Cities in Indonesia')
plt.show()

# %%
import seaborn as sns

sns.barplot(y=df['Cities'], x=df['Populations'], orient='h', color='blue')
plt.xlabel('populations of Cities')
plt.title('Populations of Cities in Indonesia')
plt.show()

# %%
import matplotlib.pyplot as plt 
flavors=('Chocolate','Vanilla','Matcha','Other')
votes=(50,20,30,10)
colors=('#8B4513', '#FFF8DC', '#93C572', '#E67F0D')
explode=(0.1,0,0,0)

plt.pie(
    x=votes,
    labels=flavors,
    colors=colors,
    wedgeprops={'width':0.4}
)
plt.show()
